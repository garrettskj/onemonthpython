# %% [markdown]
# # import pandas

# %%
import pandas as pd

# %% [markdown]
# # importing data

# %%
names = ['id', 'title', 'year', 'rating', 'votes', 'length', 'genres']
data = pd.read_csv('imdb_top_10000.txt', sep='\t', names=names, index_col=0)

# %% [markdown]
# # exploring data

# %%
data.head(3)
# Out:
#                                      title  year  rating   votes     length  \
# id
# tt0111161  The Shawshank Redemption (1994)  1994     9.2  619479  142 mins.
# tt0110912              Pulp Fiction (1994)  1994     9.0  490065  154 mins.
# tt0137523                Fight Club (1999)  1999     8.8  458173  139 mins.
#
#                            genres
# id
# tt0111161             Crime|Drama
# tt0110912          Crime|Thriller
# tt0137523  Drama|Mystery|Thriller

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, tt0111161 to tt0279977
# Data columns (total 6 columns):
# title     10000 non-null object
# year      10000 non-null int64
# rating    10000 non-null float64
# votes     10000 non-null int64
# length    10000 non-null object
# genres    9999 non-null object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 546.9+ KB

# %%
data.describe()
# Out:
#                year        rating          votes
# count  10000.000000  10000.000000   10000.000000
# mean    1993.472800      6.386070   16604.012800
# std       14.829924      1.189933   34563.459698
# min     1950.000000      1.500000    1356.000000
# 25%     1986.000000      5.700000    2333.750000
# 50%     1998.000000      6.600000    4980.500000
# 75%     2005.000000      7.200000   15277.750000
# max     2011.000000      9.200000  619479.000000

# %% [markdown]
# # Exporting data

# %%
data.to_csv('test.csv', header=True, index=True, sep=',')

# %% [markdown]
# # sorting data

# %%
data.sort_values('rating')
# Out:
#                                                        title  year  rating  \
# id
# tt0270846                Superbabies: Baby Geniuses 2 (2004)  2004     1.5
# tt0059464                             Monster a-Go Go (1965)  1965     1.5
# tt0364986                                Ben & Arthur (2002)  2002     1.5
# tt0421051                           Daniel the Wizard (2004)  2004     1.5
# tt1309000                                  Dream Well (2009)  2009     1.5
# tt0060666                    Manos: The Hands of Fate (1966)  1966     1.5
# tt0060753                   Night Train to Mundo Fine (1966)  1966     1.5
# tt0417056                                Pledge This! (2006)  2006     1.6
# tt0057507                               The Skydivers (1963)  1963     1.6
# tt0058615                            The Starfighters (1964)  1964     1.6
# tt0473310             Ram Gopal Varma's Indian Flames (2007)  2007     1.6
# ...

# %%
data.sort_values('rating', ascending=False)
# Out:
#                                                        title  year  rating  \
# id
# tt0111161                    The Shawshank Redemption (1994)  1994     9.2
# tt0068646                               The Godfather (1972)  1972     9.2
# tt0060196              The Good, the Bad and the Ugly (1966)  1966     9.0
# tt0110912                                Pulp Fiction (1994)  1994     9.0
# tt0252487                            Outrageous Class (1975)  1975     9.0
# tt0071562                      The Godfather: Part II (1974)  1974     9.0
# tt0108052                            Schindler's List (1993)  1993     8.9
# tt0073486             One Flew Over the Cuckoo's Nest (1975)  1975     8.9
# tt0468569                             The Dark Knight (2008)  2008     8.9
# tt0050083                                12 Angry Men (1957)  1957     8.9
# tt1375666                                   Inception (2010)  2010     8.9
# ...

# %% [markdown]
# # Creating data Frames from Scratch

# %%
sample_data = {
   'tv': [230.1, 44.5, 17.2],
   'radio': [37.8, 39.3, 45.9],
   'news': [69.2, 45.1, 69.3],
   'sales': [22.1, 10.4, 9.3]
}

# %%
data2 = pd.DataFrame(sample_data)

# %%
data2
# Out:
#       tv  radio  news  sales
# 0  230.1   37.8  69.2   22.1
# 1   44.5   39.3  45.1   10.4
# 2   17.2   45.9  69.3    9.3

# %% [markdown]
# # Selecting Data

# %%
data['title']
# Out:
# id
# tt0111161                      The Shawshank Redemption (1994)
# tt0110912                                  Pulp Fiction (1994)
# tt0137523                                    Fight Club (1999)
# tt0133093                                    The Matrix (1999)
# tt1375666                                     Inception (2010)
# tt0109830                                  Forrest Gump (1994)
# tt0169547                               American Beauty (1999)
# tt0499549                                        Avatar (2009)
# tt0108052                              Schindler's List (1993)
# tt0080684    Star Wars: Episode V - The Empire Strikes Back...
# tt0372784                                 Batman Begins (2005)
# tt0114814                            The Usual Suspects (1995)
# tt0102926                      The Silence of the Lambs (1991)
# tt0120338                                       Titanic (1997)
# tt0112573                                    Braveheart (1995)
# ...

# %%
data[['title', 'rating']]
# Out:
#                                                        title  rating
# id
# tt0111161                    The Shawshank Redemption (1994)     9.2
# tt0110912                                Pulp Fiction (1994)     9.0
# tt0137523                                  Fight Club (1999)     8.8
# tt0133093                                  The Matrix (1999)     8.7
# tt1375666                                   Inception (2010)     8.9
# tt0109830                                Forrest Gump (1994)     8.7
# tt0169547                             American Beauty (1999)     8.6
# tt0499549                                      Avatar (2009)     8.1
# tt0108052                            Schindler's List (1993)     8.9
# tt0080684  Star Wars: Episode V - The Empire Strikes Back...     8.8
# tt0372784                               Batman Begins (2005)     8.3
# tt0114814                          The Usual Suspects (1995)     8.7
# tt0102926                    The Silence of the Lambs (1991)     8.7
# ...

# %%
data['rating'].mean()
# Out:
# 6.38607

# %%
data['rating'].max()
# Out:
# 9.2

# %%
data['rating'].min()
# Out:
# 1.5

# %%
data['genres'].unique()
# Out:
# array(['Crime|Drama', 'Crime|Thriller', 'Drama|Mystery|Thriller', ...,
#        'Drama|War|Adventure|Romance', 'Western|Sci-Fi|Thriller',
#        'Adventure|Comedy|Drama|War'], dtype=object)

# %%
data['rating'].value_counts()
# Out:
# 6.8    401
# 7.1    401
# 7.2    386
# 6.7    384
# 7.0    382
# 6.9    374
# 6.3    354
# 6.6    339
# 6.2    330
# 7.4    327
# 7.3    326
# 6.1    307
# 6.5    301
# 7.5    291
# 6.4    284
# 7.6    284
# 5.9    278
# 5.8    269
# 6.0    267
# 5.7    251
# 7.7    238
# 5.6    226
# 7.8    224
# 8.0    187
# 5.4    186
# 7.9    182
# 5.5    163
# 5.3    162
# 5.2    157
# 5.1    149
#       ...
# 3.3     29
# 3.7     29
# 8.5     27
# 3.6     26
# 3.5     20
# 3.4     19
# 3.2     16
# 3.1     16
# 2.9     15
# 2.7     15
# 2.8     14
# 8.6     13
# 2.6     13
# 8.7     13
# 2.3     13
# 1.8     12
# 1.7     12
# 3.0     12
# 2.0     11
# 2.4      9
# 1.9      9
# 8.8      9
# 2.2      9
# 2.1      9
# 2.5      8
# 1.5      7
# 1.6      6
# 8.9      5
# 9.0      4
# 9.2      2
# Name: rating, Length: 77, dtype: int64

# %%
data['rating'].value_counts().sort_index()
# Out:
# 1.5      7
# 1.6      6
# 1.7     12
# 1.8     12
# 1.9      9
# 2.0     11
# 2.1      9
# 2.2      9
# 2.3     13
# 2.4      9
# 2.5      8
# 2.6     13
# 2.7     15
# 2.8     14
# 2.9     15
# 3.0     12
# 3.1     16
# 3.2     16
# 3.3     29
# 3.4     19
# 3.5     20
# 3.6     26
# 3.7     29
# 3.8     36
# 3.9     33
# 4.0     42
# 4.1     55
# 4.2     39
# 4.3     56
# 4.4     48
#       ...
# 6.2    330
# 6.3    354
# 6.4    284
# 6.5    301
# 6.6    339
# 6.7    384
# 6.8    401
# 6.9    374
# 7.0    382
# 7.1    401
# 7.2    386
# 7.3    326
# 7.4    327
# 7.5    291
# 7.6    284
# 7.7    238
# 7.8    224
# 7.9    182
# 8.0    187
# 8.1    115
# 8.2     78
# 8.3     52
# 8.4     41
# 8.5     27
# 8.6     13
# 8.7     13
# 8.8      9
# 8.9      5
# 9.0      4
# 9.2      2
# Name: rating, Length: 77, dtype: int64

# %%
data['rating'].value_counts().sort_index()
# Out:
# 1.5      7
# 1.6      6
# 1.7     12
# 1.8     12
# 1.9      9
# 2.0     11
# 2.1      9
# 2.2      9
# 2.3     13
# 2.4      9
# 2.5      8
# 2.6     13
# 2.7     15
# 2.8     14
# 2.9     15
# 3.0     12
# 3.1     16
# 3.2     16
# 3.3     29
# 3.4     19
# 3.5     20
# 3.6     26
# 3.7     29
# 3.8     36
# 3.9     33
# 4.0     42
# 4.1     55
# 4.2     39
# 4.3     56
# 4.4     48
#       ...
# 6.2    330
# 6.3    354
# 6.4    284
# 6.5    301
# 6.6    339
# 6.7    384
# 6.8    401
# 6.9    374
# 7.0    382
# 7.1    401
# 7.2    386
# 7.3    326
# 7.4    327
# 7.5    291
# 7.6    284
# 7.7    238
# 7.8    224
# 7.9    182
# 8.0    187
# 8.1    115
# 8.2     78
# 8.3     52
# 8.4     41
# 8.5     27
# 8.6     13
# 8.7     13
# 8.8      9
# 8.9      5
# 9.0      4
# 9.2      2
# Name: rating, Length: 77, dtype: int64

# %%
data['rating'].value_counts().sort_index(ascending=False)
# Out:
# 9.2      2
# 9.0      4
# 8.9      5
# 8.8      9
# 8.7     13
# 8.6     13
# 8.5     27
# 8.4     41
# 8.3     52
# 8.2     78
# 8.1    115
# 8.0    187
# 7.9    182
# 7.8    224
# 7.7    238
# 7.6    284
# 7.5    291
# 7.4    327
# 7.3    326
# 7.2    386
# 7.1    401
# 7.0    382
# 6.9    374
# 6.8    401
# 6.7    384
# 6.6    339
# 6.5    301
# 6.4    284
# 6.3    354
# 6.2    330
#       ...
# 4.4     48
# 4.3     56
# 4.2     39
# 4.1     55
# 4.0     42
# 3.9     33
# 3.8     36
# 3.7     29
# 3.6     26
# 3.5     20
# 3.4     19
# 3.3     29
# 3.2     16
# 3.1     16
# 3.0     12
# 2.9     15
# 2.8     14
# 2.7     15
# 2.6     13
# 2.5      8
# 2.4      9
# 2.3     13
# 2.2      9
# 2.1      9
# 2.0     11
# 1.9      9
# 1.8     12
# 1.7     12
# 1.6      6
# 1.5      7
# Name: rating, Length: 77, dtype: int64

# %%
# %matplotlib inline

# %%
data.plot()

# %%
data.plot(kind='scatter', x='rating', y='votes')

# %%
data.plot(kind='scatter', x='rating', y='votes', alpha=.3)

# %%
data['rating'].plot(kind="hist")

# %%
import seaborn as sns

# %%
sns.pairplot(data)

# %%
sns.lmplot(x='rating', y='votes', data=data)

# %% [markdown]
# # Ordinary Least Squares (OLS) Regression

# %%
import statsmodels.api as sm

# %%
results = sm.OLS(data["votes"], data["rating"]).fit()

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  votes   R-squared:                       0.221
# Model:                            OLS   Adj. R-squared:                  0.220
# Method:                 Least Squares   F-statistic:                     2829.
# Date:                Fri, 22 Mar 2019   Prob (F-statistic):               0.00
# Time:                        19:11:27   Log-Likelihood:            -1.1849e+05
# No. Observations:               10000   AIC:                         2.370e+05
# Df Residuals:                    9999   BIC:                         2.370e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# rating      2771.9868     52.115     53.190      0.000    2669.831    2874.143
# ...

# %% [markdown]
# # advanced data selection

# %%
data[data['year'] > 1995]
# Out:
#                                                        title  year  rating  \
# id
# tt0137523                                  Fight Club (1999)  1999     8.8
# tt0133093                                  The Matrix (1999)  1999     8.7
# tt1375666                                   Inception (2010)  2010     8.9
# tt0169547                             American Beauty (1999)  1999     8.6
# tt0499549                                      Avatar (2009)  2009     8.1
# tt0372784                               Batman Begins (2005)  2005     8.3
# tt0120338                                     Titanic (1997)  1997     7.4
# tt0167404                             The Sixth Sense (1999)  1999     8.2
# tt0266697                           Kill Bill: Vol. 1 (2003)  2003     8.2
# tt0416449                                         300 (2006)  2006     7.8
# tt0482571                                The Prestige (2006)  2006     8.4
# ...

# %%
data[data['year'] == 1966]
# Out:
#                                                        title  year  rating  \
# id
# tt0060196              The Good, the Bad and the Ugly (1966)  1966     9.0
# tt0061184             Who's Afraid of Virginia Woolf? (1966)  1966     8.2
# tt0060666                    Manos: The Hands of Fate (1966)  1966     1.5
# tt0060827                                     Persona (1966)  1966     8.2
# tt0060176                                     Blow-Up (1966)  1966     7.6
# tt0058946                       The Battle of Algiers (1966)  1966     8.3
# tt0060390                              Fahrenheit 451 (1966)  1966     7.2
# tt0060665                       A Man for All Seasons (1966)  1966     8.0
# tt0061452                               Casino Royale (1966)  1966     5.2
# tt0060107                               Andrei Rublev (1966)  1966     8.2
# tt0060153                                      Batman (1966)  1966     6.3
# ...

# %%
data[(data['year'] > 1995) & (data['year'] < 2000)]
# Out:
#                                                        title  year  rating  \
# id
# tt0137523                                  Fight Club (1999)  1999     8.8
# tt0133093                                  The Matrix (1999)  1999     8.7
# tt0169547                             American Beauty (1999)  1999     8.6
# tt0120338                                     Titanic (1997)  1997     7.4
# tt0167404                             The Sixth Sense (1999)  1999     8.2
# tt0120689                              The Green Mile (1999)  1999     8.4
# tt0120815                         Saving Private Ryan (1998)  1998     8.5
# tt0120586                          American History X (1998)  1998     8.6
# tt0119488                           L.A. Confidential (1997)  1997     8.4
# tt0120915   Star Wars: Episode I - The Phantom Menace (1999)  1999     6.4
# tt0118715                            The Big Lebowski (1998)  1998     8.2
# ...

# %%
data[(data['year'] > 1995) & (data['year'] < 2000)].sort_values(by='rating', ascending=False).head(10)
# Out:
#                                 title  year  rating   votes     length  \
# id
# tt0137523           Fight Club (1999)  1999     8.8  458173  139 mins.
# tt0133093           The Matrix (1999)  1999     8.7  448114  136 mins.
# tt0120586   American History X (1998)  1998     8.6  270082  119 mins.
# tt0169547      American Beauty (1999)  1999     8.6  338332  122 mins.
# tt0118799    Life Is Beautiful (1997)  1997     8.5  131578  116 mins.
# tt0120815  Saving Private Ryan (1998)  1998     8.5  317912  169 mins.
# tt0119488    L.A. Confidential (1997)  1997     8.4  187115  138 mins.
# tt0119698    Princess Mononoke (1997)  1997     8.4   77859  134 mins.
# tt0120689       The Green Mile (1999)  1999     8.4  243660  189 mins.
# tt0128332            Innocence (1997)  1997     8.3    2402  110 mins.
#
#                                  genres
# id
# tt0137523        Drama|Mystery|Thriller
# tt0133093       Action|Adventure|Sci-Fi
# tt0120586                   Crime|Drama
# ...

# %%
data.groupby(data['year'])['rating'].mean()
# Out:
# year
# 1950    7.545161
# 1951    7.478125
# 1952    7.475676
# 1953    7.106383
# 1954    7.371795
# 1955    7.250943
# 1956    7.139130
# 1957    7.486364
# 1958    7.137500
# 1959    6.767308
# 1960    7.247917
# 1961    7.195349
# 1962    7.349057
# 1963    7.103922
# 1964    6.865217
# 1965    6.996875
# 1966    6.895652
# 1967    7.169091
# 1968    6.967213
# 1969    7.011321
# 1970    6.987692
# 1971    7.058904
# 1972    6.910667
# 1973    7.133784
# 1974    6.861972
# 1975    6.850000
# 1976    6.751429
# 1977    6.691139
# 1978    6.578824
# 1979    6.685714
#           ...
# 1982    6.518557
# 1983    6.282075
# 1984    6.233333
# 1985    6.228169
# 1986    6.177124
# 1987    6.200000
# 1988    6.075401
# 1989    6.153704
# 1990    6.115607
# 1991    6.177515
# 1992    6.280541
# 1993    6.173516
# 1994    6.081277
# 1995    6.236596
# 1996    6.064906
# 1997    6.217279
# 1998    6.291349
# 1999    6.306734
# 2000    6.256135
# 2001    6.284419
# 2002    6.257754
# ...

# %%
data.groupby(data['year'])['rating'].max()
# Out:
# year
# 1950    8.7
# 1951    8.3
# 1952    8.4
# 1953    8.3
# 1954    8.8
# 1955    8.3
# 1956    8.2
# 1957    8.9
# 1958    8.5
# 1959    8.6
# 1960    8.7
# 1961    8.4
# 1962    8.5
# 1963    8.3
# 1964    8.6
# 1965    8.3
# 1966    9.0
# 1967    8.3
# 1968    8.8
# 1969    8.2
# 1970    8.1
# 1971    8.5
# 1972    9.2
# 1973    8.4
# 1974    9.0
# 1975    9.0
# 1976    8.7
# 1977    8.8
# 1978    8.5
# 1979    8.6
#        ...
# 1982    8.4
# 1983    8.3
# 1984    8.5
# 1985    8.5
# 1986    8.5
# 1987    8.5
# 1988    8.5
# 1989    8.3
# 1990    8.8
# 1991    8.7
# 1992    8.4
# 1993    8.9
# 1994    9.2
# 1995    8.7
# 1996    8.3
# 1997    8.5
# 1998    8.6
# 1999    8.8
# 2000    8.7
# 2001    8.8
# 2002    8.8
# 2003    8.8
# 2004    8.5
# 2005    8.7
# 2006    8.5
# 2007    8.3
# 2008    8.9
# 2009    8.4
# 2010    8.9
# 2011    8.6
# Name: rating, Length: 62, dtype: float64

# %%
data.groupby(data['year'])['rating'].min()
# Out:
# year
# 1950    6.3
# 1951    6.2
# 1952    6.3
# 1953    2.9
# 1954    6.1
# 1955    3.7
# 1956    3.1
# 1957    6.3
# 1958    2.9
# 1959    1.9
# 1960    2.3
# 1961    1.7
# 1962    2.1
# 1963    1.6
# 1964    1.6
# 1965    1.5
# 1966    1.5
# 1967    5.3
# 1968    1.8
# 1969    2.8
# 1970    4.0
# 1971    1.6
# 1972    3.8
# 1973    3.6
# 1974    4.4
# 1975    2.3
# 1976    1.8
# 1977    3.2
# 1978    2.3
# 1979    3.3
#        ...
# 1982    2.9
# 1983    1.8
# 1984    1.9
# 1985    1.9
# 1986    2.0
# 1987    2.1
# 1988    1.7
# 1989    1.9
# 1990    1.7
# 1991    2.3
# 1992    3.3
# 1993    2.4
# 1994    2.0
# 1995    1.7
# 1996    1.7
# 1997    1.9
# 1998    1.9
# 1999    2.2
# 2000    1.9
# 2001    2.0
# 2002    1.5
# 2003    1.7
# 2004    1.5
# 2005    1.7
# 2006    1.6
# 2007    1.6
# 2008    1.7
# 2009    1.5
# 2010    2.2
# 2011    2.1
# Name: rating, Length: 62, dtype: float64

# %% [markdown]
# # challenges

# %%
data[data['year'] == 1996].sort_values(by='rating', ascending=False)
# Out:
#                                                title  year  rating   votes  \
# id
# tt0116282                               Fargo (1996)  1996     8.3  187498
# tt0116231                          The Bandit (1996)  1996     8.3   13288
# tt0117951                       Trainspotting (1996)  1996     8.2  175993
# tt0117666                         Sling Blade (1996)  1996     8.0   44316
# tt0117589                      Secrets & Lies (1996)  1996     8.0   15435
# tt0117905       Comrades: Almost a Love Story (1996)  1996     7.8    1673
# tt0115751                  Breaking the Waves (1996)  1996     7.8   24625
# tt0117615                     Shall We Dance? (1996)  1996     7.8    6383
# tt0116630                          Hindustani (1996)  1996     7.7    1702
# tt0127311              Somersault in a Coffin (1996)  1996     7.7    1544
# tt0116790                               Kolya (1996)  1996     7.7    7480
# ...

# %%
data[data['rating'] == data['rating'].max()]
# Out:
#                                      title  year  rating   votes     length  \
# id
# tt0111161  The Shawshank Redemption (1994)  1994     9.2  619479  142 mins.
# tt0068646             The Godfather (1972)  1972     9.2  474189  175 mins.
#
#                 genres
# id
# tt0111161  Crime|Drama
# tt0068646  Crime|Drama

# %%
data.sort_values(by='votes', ascending=False).head(5)
# Out:
#                                      title  year  rating   votes     length  \
# id
# tt0111161  The Shawshank Redemption (1994)  1994     9.2  619479  142 mins.
# tt0468569           The Dark Knight (2008)  2008     8.9  555122  152 mins.
# tt0110912              Pulp Fiction (1994)  1994     9.0  490065  154 mins.
# tt0068646             The Godfather (1972)  1972     9.2  474189  175 mins.
# tt0137523                Fight Club (1999)  1999     8.8  458173  139 mins.
#
#                                 genres
# id
# tt0111161                  Crime|Drama
# tt0468569  Action|Crime|Drama|Thriller
# tt0110912               Crime|Thriller
# tt0068646                  Crime|Drama
# tt0137523       Drama|Mystery|Thriller

# %%
data[(data['year'] >= 1960) & (data['year'] <= 1970)].groupby(data['year'])['rating'].mean().sort_values(ascending=False)
# Out:
# year
# 1962    7.349057
# 1960    7.247917
# 1961    7.195349
# 1967    7.169091
# 1963    7.103922
# 1969    7.011321
# 1965    6.996875
# 1970    6.987692
# 1968    6.967213
# 1966    6.895652
# 1964    6.865217
# Name: rating, dtype: float64

# %% [markdown]
# # cleaning data

# %%
data['formatted_title'] = data['title'].str.split(' \(').str[0]

# %%
data.head()
# Out:
#                                      title  year  rating   votes     length  \
# id
# tt0111161  The Shawshank Redemption (1994)  1994     9.2  619479  142 mins.
# tt0110912              Pulp Fiction (1994)  1994     9.0  490065  154 mins.
# tt0137523                Fight Club (1999)  1999     8.8  458173  139 mins.
# tt0133093                The Matrix (1999)  1999     8.7  448114  136 mins.
# tt1375666                 Inception (2010)  2010     8.9  385149  148 mins.
#
#                                      genres           formatted_title
# id
# tt0111161                       Crime|Drama  The Shawshank Redemption
# tt0110912                    Crime|Thriller              Pulp Fiction
# tt0137523            Drama|Mystery|Thriller                Fight Club
# tt0133093           Action|Adventure|Sci-Fi                The Matrix
# tt1375666  Action|Adventure|Sci-Fi|Thriller                 Inception

# %%
data['formatted_length'] = data['length'].str.replace(' mins.', '').astype('int')

# %%
data.head()
# Out:
#                                      title  year  rating   votes     length  \
# id
# tt0111161  The Shawshank Redemption (1994)  1994     9.2  619479  142 mins.
# tt0110912              Pulp Fiction (1994)  1994     9.0  490065  154 mins.
# tt0137523                Fight Club (1999)  1999     8.8  458173  139 mins.
# tt0133093                The Matrix (1999)  1999     8.7  448114  136 mins.
# tt1375666                 Inception (2010)  2010     8.9  385149  148 mins.
#
#                                      genres           formatted_title  \
# id
# tt0111161                       Crime|Drama  The Shawshank Redemption
# tt0110912                    Crime|Thriller              Pulp Fiction
# tt0137523            Drama|Mystery|Thriller                Fight Club
# tt0133093           Action|Adventure|Sci-Fi                The Matrix
# tt1375666  Action|Adventure|Sci-Fi|Thriller                 Inception
#
#            formatted_length
# id
# tt0111161               142
# ...

# %%
sns.pairplot(data)
